# %%
import matplotlib.pyplot as plt
import numpy as np


temps = []

for line in open(r'/home/elyas/Bureau/github/projet_N_corps_git/git/Projet-N-corps/src/donnees_temps.txt'):
    lines = [ i for i in line.split()]
    temps.append(lines[0])

print(temps)


taille = len(temps)
x = np.linspace(0,1,taille)

plt.figure(figsize=(10,10))
plt.tick_params(labelleft = False )
plt.plot(x, temps)
plt.title("Graphique reprensentant le temps passé dans les calculs de notre model à N-corps")
plt.ylabel('temps des calculs')
plt.show()
# plt.savefig( "/home/elyas/Bureau/github/projet_N_corps_git/git/Projet-N-corps/visuels/Graphique_durée_des_calculs.png")
# Out:
# ['0.013141', '0.000573', '0.000538', '0.000516', '0.000513', '0.000566', '0.006822', '0.000664', '0.000656', '0.000652', '0.000632', '0.000747', '0.000626', '0.000642', '0.000675', '0.005965', '0.000773', '0.000595', '0.000693', '0.000562', '0.000692', '0.000706', '0.000696', '0.000695', '0.000582', '0.000713', '0.000562', '0.000684', '0.000525', '0.000797', '0.000642', '0.000731', '0.002254', '0.000766', '0.000769', '0.003535', '0.000653', '0.000692', '0.002643', '0.002411', '0.000685', '0.002217', '0.001837', '0.00077', '0.00254', '0.000745', '0.000648', '0.000722', '0.000684', '0.000568', '0.000758', '0.000603', '0.000615', '0.001933', '0.002036', '0.001585', '0.00048', '0.002614', '0.002117', '0.000651', '0.001791', '0.000526', '0.000642', '0.00306', '0.000586', '0.000689', '0.000554', '0.000665', '0.000641', '0.00056', '0.000529', '0.003149', '0.00056', '0.001723', '0.000445', '0.000552', '0.001789', '0.000621', '0.00052', '0.000562', '0.00044', '0.000553', '0.001794', '0.000519', '0.000522', '0.000526', '0.000527', '0.00056', '0.000532', '0.002484', '0.001424', '0.003895', '0.002337', '0.000471', '0.000552', '0.000512', '0.000531', '0.000497', '0.000536', '0.000456', '0.000481', '0.000533', '0.000485']
